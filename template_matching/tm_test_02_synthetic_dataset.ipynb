# %%
import os
import numpy as np
import cv2 as cv
import time
from matplotlib import pyplot as plt
import json


TEMPLATES_PATH = 'templates/'
IMAGES_PATH = '../Synthetic-Dataset/output/'
DATASET_JSON = '../Synthetic-Dataset/output/dataset_info.json'

# Grid search parameters
MIN_MATCH_COUNTS = [3,5,10,15,20,25]
MAXDIST = [0.8, 0.85, 0.9, 0.95]
DETECTORS = ['ORB']
MATCHERS = ['BF']
MATCHERS_PARAMS = {
	'FLANN': {
		'trees': [5,10,20],
		'checks': [50]
	},
	'BF': {
		'crossCheck': [False],
	}
}

# %% [markdown]
# # 🛠️ Utilities

# %%
def get_RGB_from_BGR(img):
	return cv.cvtColor(img, cv.COLOR_BGR2RGB)

def get_tresh_from_path(img):
    img = cv.imread(img, cv.IMREAD_GRAYSCALE)
    _, img = cv.threshold(img, 128, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
    return img

# %%
def getKeypointDetectorAndNorm(name):
    if name == "SIFT":
        return cv.SIFT_create(), cv.NORM_L2
    elif name == "SURF":
        return cv.xfeatures2d.SURF_create(), cv.NORM_L2
    elif name == "ORB":
        return cv.ORB_create(), cv.NORM_HAMMING
    elif name == "BRISK":
        return cv.BRISK_create(), cv.NORM_HAMMING
    elif name == "AKAZE":
        return cv.AKAZE_create(), cv.NORM_HAMMING
    else:
        raise Exception("Unknown keypoint detector")

# %%
def getMatcher(name, params):
	if name == "FLANN":
		FLANN_INDEX_KDTREE = 1
		index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = params['trees'])
		search_params = dict(checks = params['checks'])	
		return cv.FlannBasedMatcher(index_params, search_params)
	elif name == "BF":
		return cv.BFMatcher(params['norm'], params['crossCheck'])
	else:
		raise Exception("Unknown matcher")

# %%
def center_crop(img, factor=0.97):
	# Cropping because many templates have angle brackets at the corners
	if factor != 1:
		height, width = img.shape[:2]
		# Calculate new dimensions
		new_height = int(height * factor)
		new_width = int(width * factor)

		# Calculate top-left corner and bottom-right corner for cropping
		start_x = (width - new_width) // 2
		start_y = (height - new_height) // 2
		end_x = start_x + new_width
		end_y = start_y + new_height

		# Crop the image
		return img[start_y:end_y, start_x:end_x]
	else:
		return img

# %%
def get_draw(kp_t, kp_img, template, full_img, good):
	src_pts = np.float32([ kp_t[m.queryIdx].pt for m in good]).reshape(-1,1,2)
	dst_pts = np.float32([ kp_img[m.trainIdx].pt for m in good]).reshape(-1,1,2)
	M, mask = cv.findHomography(src_pts, dst_pts, cv.RANSAC,5.0)
	matchesMask = mask.ravel().tolist()
	template_img = cv.imread(template)
	img_img = cv.imread(full_img)
	h,w = template_img.shape[:2]
	pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
	dst = cv.perspectiveTransform(pts,M)
	img2 = cv.polylines(img_img,[np.int32(dst)],True,255,3, cv.LINE_AA)
	draw_params = dict(matchColor = (0,255,0), # draw matches in green color
				singlePointColor = None,
				matchesMask = matchesMask, # draw only inliers
				flags = 2)
	match_img = cv.drawMatches(template_img,kp_t,img2,kp_img,good,None,**draw_params)
	return match_img

def draw_match(match_img):
	plt.imshow(get_RGB_from_BGR(match_img))

# %%
def get_img_dicts(detector, treshold=False, scale=1):
  images = {}
  # Read dataset.json file
  with open(DATASET_JSON) as json_file:
    for tp in json.load(json_file)['images']:
      images[tp['combined_image_file']] = {
        'name' : tp['combined_image_file'],
        'templates' : [template['template_file'] for template in tp['templates']]
      }

  for image in images:
    ref_img = get_tresh_from_path(IMAGES_PATH + image) if treshold else cv.imread(IMAGES_PATH + image)
    if scale != 1:
      ref_img = cv.resize(ref_img, (0,0), fx=scale, fy=scale)
    kp_image, des_image = detector.detectAndCompute(ref_img, None)
    images[image]['keypoints'] = kp_image
    images[image]['descriptors'] = des_image
  
  print(f"Loaded {len(images)} images")
  return images

def get_template_dicts(detector, treshold=False):
  templates = {}
  # Find all images in the templates folder
  for path in os.listdir(TEMPLATES_PATH):
    if not path == '.DS_Store':
      templates[path] = {
        'name': path
      }
  
  for template in templates:
    template_img = get_tresh_from_path(TEMPLATES_PATH + template) if treshold else cv.imread(TEMPLATES_PATH + template)
    #template_img = center_crop(template_img) # commenting this because the corner problem has been solved in the template preprocessing
    kp_template, des_template = detector.detectAndCompute(template_img, None)
    templates[template]['keypoints'] = kp_template
    templates[template]['descriptors'] = des_template
  print(f"Loaded {len(templates)} templates")
  return templates

def search_match(image, template, matcher, dist_max, min_match, save_draw=False, draw_on_found=False, verbose=False):
  kp_t, des_t = template['keypoints'], template['descriptors']
  kp_img, des_img = image['keypoints'], image['descriptors']

  should_be_found = template['name'] in image['templates']

  good = []
  if dist_max == -1:
    matches = matcher.knnMatch(des_t,des_img,k=1)
    for m in matches:
      if not m == ():
        good.append(m)
  else:
    matches = matcher.knnMatch(des_t,des_img,k=2)
    for m,n in matches:
      if m.distance < dist_max*n.distance:
        good.append(m)

  if len(good)>min_match:
    outcome = 'TP' if should_be_found else 'FP'
    if verbose:
      print(f"{outcome} found for {template['name']} on image {image['name']} with {len(good)} matches out of {min_match}")
    if save_draw:
      try:
        draw = get_draw(kp_t, kp_img, TEMPLATES_PATH+template['name'], IMAGES_PATH+image['name'], good)
      except:
        if verbose:
          print(f"[ERROR] Couldn't draw match for {template['name']} on image {image['name']} Skipping this draw")
        draw = None
      if draw_on_found:
        draw_match(draw)
    else:
      draw = None
    return draw, outcome
  else:
    outcome = 'TN' if not should_be_found else 'FN'
    if verbose:
      print(f"{outcome} found for {template['name']} on image {image['name']} with {len(good)} matches out of {min_match}")
    return None, outcome

# %%
def run_experiment(templates, detector, matcher, dist_max, min_match, verbose=False):
	results = {
		'TP' : [],
		'FP' : [],
		'TN' : [],
		'FN' : []
	}

	#templates, images = get_dicts(detector)
	images = get_img_dicts(detector)

	for image in images:
		for template in templates:
			draw, outcome = search_match(images[image], templates[template], matcher, dist_max, min_match, verbose=verbose)
			results[outcome].append("." if draw is None else draw)

	print(f"TP: {len(results['TP'])}, FP: {len(results['FP'])}, TN: {len(results['TN'])}, FN: {len(results['FN'])}")
	return results

# %%
# Perform grid search
for detector_name in DETECTORS:
  detector, norm = getKeypointDetectorAndNorm(detector_name)
  templates = get_template_dicts(detector)
  for matcher_name in MATCHERS:
    if matcher_name == 'BF':
      for crossCheck in MATCHERS_PARAMS[matcher_name]['crossCheck']:
        matcher = getMatcher(matcher_name, {'norm': norm, 'crossCheck': crossCheck})
        MAXDIST_ITER = [-1] if crossCheck else MAXDIST
        for dist_max in MAXDIST_ITER:
          for min_match in MIN_MATCH_COUNTS:
            print("\n=====================================")
            print(f"Starting run with detector: {detector_name}, matcher: {matcher_name}, crossCheck: {crossCheck}, dist_max: {dist_max}, min_match: {min_match}")
            start_time = time.time()
            results = run_experiment(templates, detector, matcher, dist_max, min_match)
            # try:
            # except Exception as e:
            # 	print(f"[ERROR] Couldn't run experiment -> {e}")
            end_time = time.time()
            print(f"Time taken: {end_time - start_time} seconds")
    elif matcher_name == 'FLANN':
      for trees in MATCHERS_PARAMS[matcher_name]['trees']:
        for checks in MATCHERS_PARAMS[matcher_name]['checks']:
            matcher = getMatcher(matcher_name, {'trees': trees, 'checks': checks})
            for dist_max in MAXDIST:
              for min_match in MIN_MATCH_COUNTS:
                print("\n=====================================")
                print(f"Starting run with detector: {detector_name}, matcher: {matcher_name}, trees: {trees}, checks: {checks}, dist_max: {dist_max}, min_match: {min_match}")
                start_time = time.time()
                try:
                  run_experiment(templates, detector, matcher, dist_max, min_match)
                except Exception as e:
                  print(f"[ERROR] Couldn't run experiment -> {e}")
                end_time = time.time()
                print(f"Time taken: {end_time - start_time} seconds")
    else:
      raise Exception("Unknown matcher")
# Out:
# Loaded 7963 templates
#
# =====================================
# Starting run with detector: ORB, matcher: BF, crossCheck: False, dist_max: 0.8, min_match: 3
# Loaded 1000 images
# [ WARN:0@1101.032] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000000_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.032] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000001_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.032] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000002_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.032] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000003_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.032] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000004_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000005_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000006_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000007_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000008_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000009_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000010_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000011_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000012_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000013_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000014_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000015_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000016_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000017_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000018_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000019_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000020_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000021_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.033] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000022_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000023_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000024_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000025_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000026_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000027_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000028_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000029_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000030_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000031_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000032_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000033_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000034_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000035_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000036_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000037_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000038_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000039_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000040_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000041_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000042_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000043_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000044_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000045_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000046_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.034] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000047_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000048_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000049_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000050_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000051_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000052_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000053_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000054_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000055_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000056_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000057_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000058_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000059_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000060_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000061_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000062_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000063_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000064_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000065_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000066_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000067_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000068_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000069_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000070_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000071_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000072_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000073_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000074_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000075_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000076_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.035] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000077_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000078_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000079_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000080_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000081_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000082_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000083_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000084_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000085_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000086_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000087_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000088_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000089_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000090_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000091_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000092_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000093_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000094_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000095_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000096_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000097_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000098_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000099_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000100_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000101_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000102_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000103_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000104_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000105_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.036] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000106_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000107_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000108_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000109_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000110_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000111_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000112_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000113_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000114_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000115_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000116_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000117_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000118_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000119_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000120_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000121_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000122_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000123_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000124_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000125_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000126_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000127_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000128_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000129_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000130_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000131_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000132_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000133_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000134_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000135_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.037] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000136_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000137_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000138_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000139_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000140_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000141_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000142_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000143_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000144_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000145_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000146_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000147_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000148_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000149_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000150_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000151_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000152_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000153_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000154_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000155_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000156_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000157_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000158_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000159_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000160_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000161_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000162_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000163_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000164_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000165_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000166_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.038] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000167_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000168_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000169_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000170_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000171_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000172_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000173_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000174_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000175_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000176_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000177_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000178_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000179_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000180_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000181_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000182_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000183_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000184_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000185_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000186_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000187_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000188_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000189_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000190_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000191_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000192_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000193_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.039] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000194_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000195_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000196_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000197_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000198_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000199_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000200_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000201_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000202_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000203_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000204_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000205_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000206_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000207_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000208_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000209_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000210_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000211_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000212_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000213_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000214_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000215_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000216_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000217_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000218_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000219_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000220_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000221_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000222_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.040] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000223_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000224_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000225_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000226_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000227_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000228_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000229_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000230_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000231_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000232_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000233_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000234_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000235_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000236_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000237_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000238_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000239_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000240_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000241_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000242_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000243_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000244_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000245_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000246_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000247_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000248_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000249_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000250_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000251_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000252_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000253_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000254_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000255_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000256_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.041] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000257_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.042] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000258_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.042] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000259_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.042] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000260_combined.png'): can't open/read file: check file path/integrity
# ...
# [ WARN:0@1101.069] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000922_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.069] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000923_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000924_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000925_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000926_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000927_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000928_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000929_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000930_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000931_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000932_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000933_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000934_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000935_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000936_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000937_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000938_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000939_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000940_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000941_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000942_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000943_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000944_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000945_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000946_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000947_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.070] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000948_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000949_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000950_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000951_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000952_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000953_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000954_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000955_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000956_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000957_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000958_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000959_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000960_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000961_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000962_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000963_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000964_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000965_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000966_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000967_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000968_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000969_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000970_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000971_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.071] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000972_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000973_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000974_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000975_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000976_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000977_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000978_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000979_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000980_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000981_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000982_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000983_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000984_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000985_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000986_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000987_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000988_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000989_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000990_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000991_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000992_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000993_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000994_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000995_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000996_combined.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000997_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000998_template_00.png'): can't open/read file: check file path/integrity
# [ WARN:0@1101.072] global loadsave.cpp:241 findDecoder imread_('../Synthetic-Dataset/output/images/images/img_000999_combined.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 15
#      13 print(f"Starting run with detector: {detector_name}, matcher: {matcher_name}, crossCheck: {crossCheck}, dist_max: {dist_max}, min_match: {min_match}")
#      14 start_time = time.time()
# ---> 15 results = run_experiment(templates, detector, matcher, dist_max, min_match)
#      16 # try:
#      17 # except Exception as e:
#      18 # 	print(f"[ERROR] Couldn't run experiment -> {e}")
#      19 end_time = time.time()
#
# Cell In[26], line 14, in run_experiment(templates, detector, matcher, dist_max, min_match, verbose)
#      12 for image in images:
#      13 	for template in templates:
# ---> 14 		draw, outcome = search_match(images[image], templates[template], matcher, dist_max, min_match, verbose=verbose)
#      15 		results[outcome].append("." if draw is None else draw)
#      17 print(f"TP: {len(results['TP'])}, FP: {len(results['FP'])}, TN: {len(results['TN'])}, FN: {len(results['FN'])}")
#
# Cell In[25], line 53, in search_match(image, template, matcher, dist_max, min_match, save_draw, draw_on_found, verbose)
#      51       good.append(m)
#      52 else:
# ---> 53   matches = matcher.knnMatch(des_t,des_img,k=2)
#      54   for m,n in matches:
#      55     if m.distance < dist_max*n.distance:
#
# error: OpenCV(4.10.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/batch_distance.cpp:275: error: (-215:Assertion failed) type == src2.type() && src1.cols == src2.cols && (type == CV_32F || type == CV_8U) in function 'batchDistance'
